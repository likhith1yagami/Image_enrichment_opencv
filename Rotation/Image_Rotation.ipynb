# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# The files are loaded from colab. So images file read and write paths need to be altered

# %%
#read image as greyscale
img1=cv2.imread('/content/rotate-1.jpg')
img2=cv2.imread('/content/rotate-2.jpg')
img3=cv2.imread('/content/rotate-3.jpg')
img4=cv2.imread('/content/rotate-4-brokenlines.jpg')
img5=cv2.imread('/content/rotate-5-brokenlines.jpg')

# %%
img1_rotate_180=cv2.rotate(img1,cv2.ROTATE_180)
img2_rotate_90_CC=cv2.rotate(img2,cv2.ROTATE_90_COUNTERCLOCKWISE)
img3_rotate_90_clockwise = cv2.rotate(img3, cv2.ROTATE_90_CLOCKWISE)

# %% [markdown]
# Rotating first image and saving it.

# %%
cv2_imshow(img1_rotate_180)
# Out:
# <PIL.Image.Image image mode=RGB size=3508x2479 at 0x7F1EE9E35E48>

# %%
cv2.imwrite('/content/rotate-1.jpg',img1_rotate_180)
# Out:
# True

# %% [markdown]
# Rotate second image and save it

# %%
cv2_imshow(img2_rotate_90_CC)
# Out:
# <PIL.Image.Image image mode=RGB size=2479x3508 at 0x7F1EE953F9B0>

# %%
cv2.imwrite('/content/rotate-2.jpg',img2_rotate_90_CC)
# Out:
# True

# %% [markdown]
# Rotating third image

# %%
cv2_imshow(img3_rotate_90_clockwise)
# Out:
# <PIL.Image.Image image mode=RGB size=816x1056 at 0x7F1EE953FA58>

# %%
cv2.imwrite('/content/rotate-3.jpg',img3_rotate_90_clockwise)
# Out:
# True

# %% [markdown]
# Rotating image 4

# %%
import cv2
import numpy as np
frame=cv2.imread('/content/rotate-4-brokenlines.JPG')
gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,150,apertureSize = 3)
minLineLength = 100
maxLineGap = 10
lines = cv2.HoughLinesP(edges,1,np.pi/180,100,minLineLength,maxLineGap)
for x1,y1,x2,y2 in lines[0]:
    cv2.line(frame,(x1,y1),(x2,y2),(0,255,0),2)

cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=662x219 at 0x7F1EE953F908>

# %%
img4rotated=cv2.rotate(frame,cv2.ROTATE_180)

# %%
cv2_imshow(img4rotated)
# Out:
# <PIL.Image.Image image mode=RGB size=662x219 at 0x7F1EE9553630>

# %%
cv2.imwrite('/content/rotate-4-brokenlines.JPG',img4rotated)
# Out:
# True

# %% [markdown]
# Rotating image 5

# %%
import cv2
import numpy as np
frame1=cv2.imread('/content/rotate-5-brokenlines.JPG')
gray = cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,150,apertureSize = 3)
minLineLength = 100
maxLineGap = 10
lines = cv2.HoughLinesP(edges,1,np.pi/180,100,minLineLength,maxLineGap)
for x1,y1,x2,y2 in lines[0]:
    cv2.line(frame1,(x1,y1),(x2,y2),(0,255,0),2)

cv2_imshow(frame1)
# Out:
# <PIL.Image.Image image mode=RGB size=322x681 at 0x7F1EE7CF4400>

# %%
img5rotated=cv2.rotate(frame1,cv2.ROTATE_90_COUNTERCLOCKWISE)

# %%
cv2_imshow(img5rotated)
# Out:
# <PIL.Image.Image image mode=RGB size=681x322 at 0x7F1EE7CF4320>

# %%
cv2.imwrite('/content/rotate-5-brokenlines.JPG',img5rotated)
# Out:
# True
